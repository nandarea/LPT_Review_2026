# %% [markdown]
# ## Positions in Galactic Coordinate for all pulsar classes including magnetars, XDINS, CCOs and  and LPTs

# %%
# %matplotlib inline
import matplotlib 
import matplotlib
params = {
    'savefig.dpi': 400, 
    'xtick.direction': 'in',
    'ytick.direction': 'in',
    'font.size': 20, 
    'text.usetex': False,
    "font.family": "Arial",
}
matplotlib.rcParams.update(params)

import matplotlib.pyplot as plt
import pandas as pd
from matplotlib import rc, rcParams
import adjustText
import os
import math
import numpy as np
from scipy import constants
from matplotlib.collections import LineCollection
from matplotlib.colors import ListedColormap
from matplotlib import colors
import scipy
import scipy.constants as sc
import astropy
import astropy.constants as astro_cons
import astropy.coordinates as coord
#import seaborn as sns
from astropy import constants as const
from astropy import units as u
from astropy.io import ascii
from astropy.coordinates import Angle

# %% [markdown]
# # Read the file generated by the ATNF

# %%
data = ascii.read("Positions_ATNF_FRB_MAG_v2.csv")  
data
# Out:
# <Table length=2964>
# CLASS    NAME     DATE    Gl      Gb
# str10   str18    int64 float64 float64
# ----- ---------- ----- ------- -------
# XDINS J1856-3754  2007 358.599 -17.215
# XDINS J1308+2127  2002 338.733  83.082
# XDINS J0420-5022  2004 258.136 -44.386
# XDINS J0806-4123  2004 257.426  -4.983
# XDINS J0720-3125  1997 244.158  -8.165
# XDINS J2143+0654  2005  62.655 -33.139
# XDINS J1605+3249  2007   52.88  47.992
#   PSR J1653-2054  2015 359.969  14.261
#   PSR J1754-3014  2006 359.862  -2.332
#   PSR J1745-2912  2006 359.788  -0.175
#   PSR J1745-2910  2009 359.763  -0.054
#   PSR J1909-3744  2003 359.731 -19.596
#   PSR J1759-3107  2004 359.629  -3.673
#   PSR   B1746-30  1992 359.459  -1.244
#   PSR J1736-2819  2004 359.446   2.036
#   PSR   B1607-13  1985 359.427  26.949
#   PSR J1747-2958  2002 359.305  -0.841
#   PSR J1748-3009  2013 359.272  -1.147
#   PSR   B1736-29  1986 359.206   1.064
#   ...        ...   ...     ...     ...
# ...

# %%
df_sources_data = pd.read_csv('PPdotB_LumkTage_allclasses_130126.csv')
df_sources_data
# Out:
#                  source     class radio      association  distance(kpc)  \
# 0    CXOUJ185238.6+0040       CCO   NaN        SNR Kes79          7.100
# 1         1E1207.4-5209       CCO   NaN  SNR G296.5+10.0          2.350
# 2        RXJ0822.0-4300       CCO   NaN      SNR PuppisA          1.300
# 3         1E161348-5055       CCO   NaN       SNR RCW103          3.300
# 4   CXOJ085201.4-461753       CCO   NaN      SNR Vela Jr          0.770
# ..                  ...       ...   ...              ...            ...
# 85      GLEAM-XJ0704-36     WDLPT  True              NaN            NaN
# 86                ARSco  WDpulsar  True              NaN          0.116
# 87           J1912-4410  WDpulsar  True              NaN          0.237
# 88        ILTJ1101+5521     WDLPT  True              NaN          0.504
# 89        CHIMEJ1634+44     WDLPT  True              NaN            NaN
#
#         l(deg)     b(deg)  period(s)  pdot(1e-11s/s) pdot_ul  ...  Err_kT_min  \
# ...

# %%
plt.rcParams.update({'font.size': 30})
plt.rcParams['figure.figsize'] = (30,20)
#fig, ax = plt.subplots()

size_points = 200
size_inside_text = 32
alpha_points = 0.9


#plt.rcParams['figure.figsize'] = (12, 18)
plt.rcParams['font.size'] = 30
#plt.rcParams['lines.linewidth'] = 2
plt.rcParams['xtick.labelsize'] = 0
plt.rcParams['ytick.labelsize'] = 32
#plt.rcParams['axes.titlesize'] = 14
plt.rcParams['legend.fontsize'] = 32


plt.set_cmap('binary')
fig = plt.figure(figsize=(30,20))
ax = fig.add_subplot(111, projection="mollweide")



idata = df_sources_data[df_sources_data['class']=='Magnetar']
l_vals = idata['l(deg)'].astype('float64').to_numpy()   # converts <NA> → np.nan
b_vals = idata['b(deg)'].astype('float64').to_numpy()
ra  = Angle(l_vals, unit=u.deg)
dec_all = Angle(b_vals, unit=u.deg)
#ra = coord.Angle(idata['l(deg)']*u.degree)
ra_all = ra.wrap_at(180*u.degree)
#dec_all = coord.Angle(idata['b(deg)']*u.degree)
aaa = ax.scatter(-ra_all.radian, dec_all.radian, c='royalblue', s=400, alpha=0.8, zorder=3, edgecolors='slategrey', marker='*', label='Magnetar-like emission')


idata = df_sources_data[df_sources_data['class']=='XDINS']
l_vals = idata['l(deg)'].astype('float64').to_numpy()   # converts <NA> → np.nan
b_vals = idata['b(deg)'].astype('float64').to_numpy()
ra  = Angle(l_vals, unit=u.deg)
dec_all = Angle(b_vals, unit=u.deg)
#ra = coord.Angle(idata['l(deg)']*u.degree)
ra_all = ra.wrap_at(180*u.degree)
#dec_all = coord.Angle(idata['b(deg)']*u.degree)
aaa = ax.scatter(-ra_all.radian, dec_all.radian, c='mediumaquamarine', s=500, alpha=0.6, zorder=2, edgecolors='slategrey', marker='s', label='Thermally emitting (XDINS)')

idata = df_sources_data[df_sources_data['class']=='CCO']
l_vals = idata['l(deg)'].astype('float64').to_numpy()   # converts <NA> → np.nan
b_vals = idata['b(deg)'].astype('float64').to_numpy()
ra  = Angle(l_vals, unit=u.deg)
dec_all = Angle(b_vals, unit=u.deg)
#ra = coord.Angle(idata['l(deg)']*u.degree)
ra_all = ra.wrap_at(180*u.degree)
#dec_all = coord.Angle(idata['b(deg)']*u.degree)
aaa = ax.scatter(-ra_all.radian, dec_all.radian, c='lightseagreen', s=500, alpha=0.8, zorder=4, edgecolors='slategrey', marker='^', label='Central Compact Objects (CCO)')

idata = df_sources_data[df_sources_data['class']=='LPT']
l_vals = idata['l(deg)'].astype('float64').to_numpy()   # converts <NA> → np.nan
b_vals = idata['b(deg)'].astype('float64').to_numpy()
ra  = Angle(l_vals, unit=u.deg)
dec_all = Angle(b_vals, unit=u.deg)
#ra = coord.Angle(idata['l(deg)']*u.degree)
ra_all = ra.wrap_at(180*u.degree)
#dec_all = coord.Angle(idata['b(deg)']*u.degree)
aaa = ax.scatter(-ra_all.radian, dec_all.radian, c='mediumspringgreen', s=700, alpha=0.8, zorder=7, marker='X', edgecolors='black', label='Long Period Transients')

idata = df_sources_data[df_sources_data['class']=='WDLPT']
l_vals = idata['l(deg)'].astype('float64').to_numpy()   # converts <NA> → np.nan
b_vals = idata['b(deg)'].astype('float64').to_numpy()
ra  = Angle(l_vals, unit=u.deg)
dec_all = Angle(b_vals, unit=u.deg)
#ra = coord.Angle(idata['l(deg)']*u.degree)
ra_all = ra.wrap_at(180*u.degree)
#dec_all = coord.Angle(idata['b(deg)']*u.degree)
aaa = ax.scatter(-ra_all.radian, dec_all.radian, c='orange', s=800, alpha=1, zorder=6, marker='X', edgecolors='black', label='WD LPTs')

idata = df_sources_data[df_sources_data['class']=='WDpulsar']
l_vals = idata['l(deg)'].astype('float64').to_numpy()   # converts <NA> → np.nan
b_vals = idata['b(deg)'].astype('float64').to_numpy()
ra  = Angle(l_vals, unit=u.deg)
dec_all = Angle(b_vals, unit=u.deg)
#ra = coord.Angle(idata['l(deg)']*u.degree)
ra_all = ra.wrap_at(180*u.degree)
#dec_all = coord.Angle(idata['b(deg)']*u.degree)
aaa = ax.scatter(-ra_all.radian, dec_all.radian, c='gold', s=800, alpha=1, zorder=6, marker='X', edgecolors='black', label='WD pulsars')

idata = data[data['CLASS']=='PSR']
#l_vals = idata['Gl'].astype('float64').to_numpy()   # converts <NA> → np.nan
#b_vals = idata['Gb'].astype('float64').to_numpy()
#ra  = Angle(l_vals, unit=u.deg)
#dec_all = Angle(b_vals, unit=u.deg)
ra = coord.Angle(idata['Gl']*u.degree)
ra_all = ra.wrap_at(180*u.degree)
dec_all = coord.Angle(idata['Gb']*u.degree)
aaa = ax.scatter(-ra_all.radian, dec_all.radian, c='grey', s=80, alpha=0.1, zorder=1, edgecolors='None')


ax.set_aspect(0.5)
ax.grid(True)

ax.legend(loc='upper right')
plt.savefig('Figure2_Positions_LPTreview.png')
plt.savefig('Figure2_Positions_LPTreview.pdf',format= 'pdf', bbox_inches="tight")
            
#plt.savefig('Figure2_Positions_LPTs_ATNF_Magnetars.pdf', bbox_inches="tight", transparent=False)    # <-- preserves transparency
